# %% [markdown]
# ## Exercise 1

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

list_mean = []


for i in range (1,7):
    number_rolls = 10**i
    random.seed(10)
    dice10 = np.random.randint(1, 7, number_rolls)
    rolls = np.mean(dice10)
    list_mean.append(rolls)

x = ['10','100','1000','10000','100000','1000000']
x_range = range(len(x))

plt.plot(list_mean, color="red", marker='o')
plt.xticks(x_range, x)
plt.show()

# %% [markdown]
# ## Exercise 2
